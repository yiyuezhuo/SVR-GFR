# %%
import pandas as pd
import numpy as np

# %%
from preprocessing import df
from empirical_formulas import apply_formulas

# %%
from IPython import display

# %%
df.head()
# Out:
#    sex  age    Cys   Scr  rGFR  FAScr  FAScys  FAScrcys  EPIcr  EPIcys  \
# 0    1   38   3.35  8.69  83.7   11.4    26.9      16.0    7.1    17.1
# 1    1   38   3.35  8.69  63.0   11.4    26.9      16.0    7.1    17.1
# 2    1   59   8.89  6.72  11.7   11.4     7.9       9.3    8.4     4.3
# 3    2   43  11.48  6.55   9.9   11.1     7.4       8.9    7.1     3.0
# 4    1   32   7.38  6.40  10.5   16.6    13.1      14.7   10.7     6.1
#
#    EPIcrcys
# 0      10.0
# 1      10.0
# 2       5.0
# 3       4.0
# 4       7.0

# %%
df.corr()
# Out:
#                sex       age       Cys       Scr      rGFR     FAScr  \
# sex       1.000000 -0.007743 -0.095576 -0.060239  0.091701 -0.083213
# age      -0.007743  1.000000  0.155757  0.308770 -0.440609 -0.680546
# Cys      -0.095576  0.155757  1.000000  0.854291 -0.656045 -0.540841
# Scr      -0.060239  0.308770  0.854291  1.000000 -0.729777 -0.725042
# rGFR      0.091701 -0.440609 -0.656045 -0.729777  1.000000  0.740067
# FAScr    -0.083213 -0.680546 -0.540841 -0.725042  0.740067  1.000000
# FAScys    0.261361 -0.536314 -0.617365 -0.671348  0.773793  0.759255
# FAScrcys  0.081258 -0.652213 -0.626052 -0.750790  0.812752  0.938154
# EPIcr    -0.100085 -0.600863 -0.599314 -0.786709  0.774939  0.978269
# EPIcys    0.200084 -0.418263 -0.717181 -0.768627  0.822765  0.752017
# EPIcrcys  0.074212 -0.517674 -0.691067 -0.808486  0.844125  0.896489
#
#             FAScys  FAScrcys     EPIcr    EPIcys  EPIcrcys
# sex       0.261361  0.081258 -0.100085  0.200084  0.074212
# age      -0.536314 -0.652213 -0.600863 -0.418263 -0.517674
# Cys      -0.617365 -0.626052 -0.599314 -0.717181 -0.691067
# Scr      -0.671348 -0.750790 -0.786709 -0.768627 -0.808486
# rGFR      0.773793  0.812752  0.774939  0.822765  0.844125
# FAScr     0.759255  0.938154  0.978269  0.752017  0.896489
# FAScys    1.000000  0.927412  0.757601  0.940487  0.915956
# FAScrcys  0.927412  1.000000  0.931711  0.903734  0.972063
# EPIcr     0.757601  0.931711  1.000000  0.791709  0.929671
# EPIcys    0.940487  0.903734  0.791709  1.000000  0.957124
# EPIcrcys  0.915956  0.972063  0.929671  0.957124  1.000000

# %%
from sklearn.svm import SVR

# %% [markdown]
# 这里为了和经验公式公平对决，使用所有样本拟合的得出的模型，其超参数在之前的测试时已保证其不会过拟合，它们的测试集分数甚至比训练集高或者至多低一个百分点。

# %%
class ModelWithTransform:
    
    def __init__(self, base_model, *, scale_method, sex_method, normalize, normalize_y):
        self.base_model = base_model
        
        assert sex_method != 'sex2'
        
        self.scale_method = scale_method
        self.sex_method = sex_method
        self.normalize = normalize
        self.normalize_y = normalize_y
        
    def encode_X(self, df):
        if self.scale_method == 'linear_scale':
            #y = df['rGFR']
            if self.sex_method == 'dummy':
                X = df[['age', 'Scr', 'Cys', 'sex']]
            else:
                X = df[['age', 'Scr', 'Cys']]

        else:
            #y = np.log(df['rGFR'])
            if self.sex_method == 'dummy':
                X = np.stack([df['age'], np.log(df['Scr']), np.log(df['Cys']), df['sex']], 1)
            else:
                X = np.stack([df['age'], np.log(df['Scr']), np.log(df['Cys'])], 1)

        if self.normalize:
            mean = X.mean(axis=0)
            std = X.std(axis=0)
            X = (X - mean)/std
        if self.normalize_y:
            raise NotImplementedError
        
        return X
    
    def encode_y(self, df):
        if self.scale_method == 'linear_scale':
            y = df['rGFR']
        else:
            y = np.log(df['rGFR'])
        
        return y
    
    def decode_y(self, y):
        if self.scale_method == 'log_scale':
            return np.exp(y)
        return y
    
    def fit(self, df):
        X = self.encode_X(df)
        y = self.encode_y(df)
        
        self.base_model.fit(X, y)
        
    def predict(self, df):
        X = self.encode_X(df)
        y_raw = self.base_model.predict(X)
        y = self.decode_y(y_raw)
        return y

# %%
model_t = ModelWithTransform(SVR(kernel='rbf', C=100.0, gamma=0.1, epsilon=0.05), 
                    scale_method = 'log_scale',
                    sex_method = 'dummy',
                    normalize = True,
                    normalize_y = False)

# %%
model_t.fit(df)

# %%
model_t.predict(df)
# Out:
# array([ 66.23581572,  66.23581572,   8.82708882, ..., 123.49917747,
#        120.52058624,  74.58182062])

# %%
df['SVR'] = model_t.predict(df)

# %%
df.corr()
# Out:
#                sex       age       Cys       Scr      rGFR     FAScr  \
# sex       1.000000 -0.007743 -0.095576 -0.060239  0.091701 -0.083213
# age      -0.007743  1.000000  0.155757  0.308770 -0.440609 -0.680546
# Cys      -0.095576  0.155757  1.000000  0.854291 -0.656045 -0.540841
# Scr      -0.060239  0.308770  0.854291  1.000000 -0.729777 -0.725042
# rGFR      0.091701 -0.440609 -0.656045 -0.729777  1.000000  0.740067
# FAScr    -0.083213 -0.680546 -0.540841 -0.725042  0.740067  1.000000
# FAScys    0.261361 -0.536314 -0.617365 -0.671348  0.773793  0.759255
# FAScrcys  0.081258 -0.652213 -0.626052 -0.750790  0.812752  0.938154
# EPIcr    -0.100085 -0.600863 -0.599314 -0.786709  0.774939  0.978269
# EPIcys    0.200084 -0.418263 -0.717181 -0.768627  0.822765  0.752017
# EPIcrcys  0.074212 -0.517674 -0.691067 -0.808486  0.844125  0.896489
# SVR       0.093741 -0.504135 -0.753731 -0.844822  0.865759  0.860934
#
#             FAScys  FAScrcys     EPIcr    EPIcys  EPIcrcys       SVR
# sex       0.261361  0.081258 -0.100085  0.200084  0.074212  0.093741
# age      -0.536314 -0.652213 -0.600863 -0.418263 -0.517674 -0.504135
# Cys      -0.617365 -0.626052 -0.599314 -0.717181 -0.691067 -0.753731
# Scr      -0.671348 -0.750790 -0.786709 -0.768627 -0.808486 -0.844822
# rGFR      0.773793  0.812752  0.774939  0.822765  0.844125  0.865759
# FAScr     0.759255  0.938154  0.978269  0.752017  0.896489  0.860934
# FAScys    1.000000  0.927412  0.757601  0.940487  0.915956  0.892676
# FAScrcys  0.927412  1.000000  0.931711  0.903734  0.972063  0.941364
# EPIcr     0.757601  0.931711  1.000000  0.791709  0.929671  0.901047
# EPIcys    0.940487  0.903734  0.791709  1.000000  0.957124  0.948592
# EPIcrcys  0.915956  0.972063  0.929671  0.957124  1.000000  0.977194
# SVR       0.892676  0.941364  0.901047  0.948592  0.977194  1.000000

# %%
apply_formulas(df)
df.corr()
# Out:
#                      sex       age       Cys       Scr      rGFR     FAScr  \
# sex             1.000000 -0.007743 -0.095576 -0.060239  0.091701 -0.083213
# age            -0.007743  1.000000  0.155757  0.308770 -0.440609 -0.680546
# Cys            -0.095576  0.155757  1.000000  0.854291 -0.656045 -0.540841
# Scr            -0.060239  0.308770  0.854291  1.000000 -0.729777 -0.725042
# rGFR            0.091701 -0.440609 -0.656045 -0.729777  1.000000  0.740067
# FAScr          -0.083213 -0.680546 -0.540841 -0.725042  0.740067  1.000000
# FAScys          0.261361 -0.536314 -0.617365 -0.671348  0.773793  0.759255
# FAScrcys        0.081258 -0.652213 -0.626052 -0.750790  0.812752  0.938154
# EPIcr          -0.100085 -0.600863 -0.599314 -0.786709  0.774939  0.978269
# EPIcys          0.200084 -0.418263 -0.717181 -0.768627  0.822765  0.752017
# EPIcrcys        0.074212 -0.517674 -0.691067 -0.808486  0.844125  0.896489
# SVR             0.093741 -0.504135 -0.753731 -0.844822  0.865759  0.860934
# CKD_EPI_Cr     -0.081871 -0.602757 -0.601871 -0.789165  0.778504  0.978391
# CKD_EPI_Cys     0.200089 -0.418232 -0.717176 -0.768638  0.822771  0.752014
# CKD_EPI_Cr_Cys  0.074111 -0.517767 -0.691028 -0.808378  0.844254  0.896506
# FAS_cr         -0.090783 -0.623763 -0.566568 -0.755141  0.753606  0.987302
# FAS_Cys         0.274252 -0.476405 -0.646483 -0.696687  0.786980  0.735510
# FAS_Cr_Cys      0.083872 -0.593327 -0.658845 -0.784444  0.831135  0.922982
#
#                   FAScys  FAScrcys     EPIcr    EPIcys  EPIcrcys       SVR  \
# sex             0.261361  0.081258 -0.100085  0.200084  0.074212  0.093741
# age            -0.536314 -0.652213 -0.600863 -0.418263 -0.517674 -0.504135
# Cys            -0.617365 -0.626052 -0.599314 -0.717181 -0.691067 -0.753731
# Scr            -0.671348 -0.750790 -0.786709 -0.768627 -0.808486 -0.844822
# rGFR            0.773793  0.812752  0.774939  0.822765  0.844125  0.865759
# FAScr           0.759255  0.938154  0.978269  0.752017  0.896489  0.860934
# FAScys          1.000000  0.927412  0.757601  0.940487  0.915956  0.892676
# FAScrcys        0.927412  1.000000  0.931711  0.903734  0.972063  0.941364
# EPIcr           0.757601  0.931711  1.000000  0.791709  0.929671  0.901047
# EPIcys          0.940487  0.903734  0.791709  1.000000  0.957124  0.948592
# EPIcrcys        0.915956  0.972063  0.929671  0.957124  1.000000  0.977194
# SVR             0.892676  0.941364  0.901047  0.948592  0.977194  1.000000
# CKD_EPI_Cr      0.765593  0.935844  0.999743  0.797619  0.933337  0.904832
# CKD_EPI_Cys     0.940484  0.903728  0.791709  1.000000  0.957124  0.948592
# CKD_EPI_Cr_Cys  0.915898  0.972045  0.929721  0.957136  0.999967  0.977220
# FAS_cr          0.741709  0.922504  0.982411  0.762055  0.905356  0.876483
# FAS_Cys         0.988484  0.909042  0.749873  0.957963  0.922850  0.907298
# FAS_Cr_Cys      0.916626  0.987055  0.934564  0.922992  0.985555  0.962233
#
#                 CKD_EPI_Cr  CKD_EPI_Cys  CKD_EPI_Cr_Cys    FAS_cr   FAS_Cys  \
# sex              -0.081871     0.200089        0.074111 -0.090783  0.274252
# age              -0.602757    -0.418232       -0.517767 -0.623763 -0.476405
# Cys              -0.601871    -0.717176       -0.691028 -0.566568 -0.646483
# Scr              -0.789165    -0.768638       -0.808378 -0.755141 -0.696687
# rGFR              0.778504     0.822771        0.844254  0.753606  0.786980
# FAScr             0.978391     0.752014        0.896506  0.987302  0.735510
# FAScys            0.765593     0.940484        0.915898  0.741709  0.988484
# FAScrcys          0.935844     0.903728        0.972045  0.922504  0.909042
# EPIcr             0.999743     0.791709        0.929721  0.982411  0.749873
# EPIcys            0.797619     1.000000        0.957136  0.762055  0.957963
# EPIcrcys          0.933337     0.957124        0.999967  0.905356  0.922850
# SVR               0.904832     0.948592        0.977220  0.876483  0.907298
# CKD_EPI_Cr        1.000000     0.797619        0.933386  0.982382  0.758070
# CKD_EPI_Cys       0.797619     1.000000        0.957136  0.762052  0.957960
# CKD_EPI_Cr_Cys    0.933386     0.957136        1.000000  0.905412  0.922825
# FAS_cr            0.982382     0.762052        0.905412  1.000000  0.739676
# FAS_Cys           0.758070     0.957960        0.922825  0.739676  1.000000
# FAS_Cr_Cys        0.938746     0.922987        0.985576  0.932318  0.921881
#
#                 FAS_Cr_Cys
# sex               0.083872
# age              -0.593327
# Cys              -0.658845
# Scr              -0.784444
# rGFR              0.831135
# FAScr             0.922982
# FAScys            0.916626
# FAScrcys          0.987055
# EPIcr             0.934564
# EPIcys            0.922992
# EPIcrcys          0.985555
# SVR               0.962233
# CKD_EPI_Cr        0.938746
# CKD_EPI_Cys       0.922987
# CKD_EPI_Cr_Cys    0.985576
# FAS_cr            0.932318
# FAS_Cys           0.921881
# FAS_Cr_Cys        1.000000

# %%
def desc(df, key_obs, key_pred):
    rd = {}
    for key,_df in zip(["All subjects", "Age<60 y", "Age>=60y"],[df, df[df['age']<60], df[df['age']>=60]]):
        y_pred = _df[key_pred]
        rd[key] = '{}({})'.format(y_pred.mean(), y_pred.std())
    return rd

# %%
def batch_apply(df, f):
    key_obs = 'rGFR'
    record = []
    keys = ['CKD_EPI_Cys', 'CKD_EPI_Cr_Cys', 'FAS_Cys', 'FAS_Cr_Cys', 'SVR']
    for key_pred in keys:
        r = f(df, key_obs, key_pred)
        record.append(r)
    rdf = pd.DataFrame(record)
    rdf.index = keys
    return rdf

# %%
batch_apply(df, desc)
# Out:
#                                           All subjects  \
# CKD_EPI_Cys         69.3962085948395(39.1517378356909)
# CKD_EPI_Cr_Cys    64.27641958959802(35.48006790892703)
# FAS_Cys          71.88361925596095(42.466317375049705)
# FAS_Cr_Cys      63.847679107672455(33.528004610544365)
# SVR              65.30995460395278(25.639187542415552)
#
#                                             Age<60 y  \
# CKD_EPI_Cys     80.90386106107096(39.14754940746409)
# CKD_EPI_Cr_Cys   77.0652300118479(34.95017038821175)
# FAS_Cys          86.3526842984172(44.56617013166695)
# FAS_Cr_Cys      78.02836674241843(32.74794994389674)
# SVR             74.75305834407989(24.30807419863831)
#
#                                              Age>=60y
# CKD_EPI_Cys     51.993331519253275(32.12753816195782)
# CKD_EPI_Cr_Cys  44.936063563511276(26.36529880065677)
# FAS_Cys         50.00223544884381(27.080307487568675)
# FAS_Cr_Cys      42.40240480181842(20.953145653776453)
# SVR              51.0292684185053(20.488751506424602)

# %% [markdown]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>age</th>
#       <th>Cys</th>
#       <th>Scr</th>
#       <th>rGFR</th>
#       <th>FAScr</th>
#       <th>FAScys</th>
#       <th>FAScrcys</th>
#       <th>EPIcr</th>
#       <th>EPIcys</th>
#       <th>EPIcrcys</th>
#       <th>SVR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>38</td>
#       <td>3.35</td>
#       <td>8.69</td>
#       <td>83.7</td>
#       <td>11.4</td>
#       <td>26.9</td>
#       <td>16.0</td>
#       <td>7.1</td>
#       <td>17.1</td>
#       <td>10.0</td>
#       <td>66.235816</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>38</td>
#       <td>3.35</td>
#       <td>8.69</td>
#       <td>63.0</td>
#       <td>11.4</td>
#       <td>26.9</td>
#       <td>16.0</td>
#       <td>7.1</td>
#       <td>17.1</td>
#       <td>10.0</td>
#       <td>66.235816</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>59</td>
#       <td>8.89</td>
#       <td>6.72</td>
#       <td>11.7</td>
#       <td>11.4</td>
#       <td>7.9</td>
#       <td>9.3</td>
#       <td>8.4</td>
#       <td>4.3</td>
#       <td>5.0</td>
#       <td>8.827089</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>43</td>
#       <td>11.48</td>
#       <td>6.55</td>
#       <td>9.9</td>
#       <td>11.1</td>
#       <td>7.4</td>
#       <td>8.9</td>
#       <td>7.1</td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>10.407108</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>32</td>
#       <td>7.38</td>
#       <td>6.40</td>
#       <td>10.5</td>
#       <td>16.6</td>
#       <td>13.1</td>
#       <td>14.7</td>
#       <td>10.7</td>
#       <td>6.1</td>
#       <td>7.0</td>
#       <td>12.091119</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>59</td>
#       <td>11.49</td>
#       <td>6.38</td>
#       <td>16.2</td>
#       <td>9.4</td>
#       <td>6.1</td>
#       <td>7.4</td>
#       <td>6.6</td>
#       <td>2.8</td>
#       <td>4.0</td>
#       <td>15.405799</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2</td>
#       <td>73</td>
#       <td>8.47</td>
#       <td>6.35</td>
#       <td>13.9</td>
#       <td>7.9</td>
#       <td>8.1</td>
#       <td>8.0</td>
#       <td>6.0</td>
#       <td>4.0</td>
#       <td>4.0</td>
#       <td>14.526554</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2</td>
#       <td>39</td>
#       <td>8.15</td>
#       <td>6.29</td>
#       <td>11.5</td>
#       <td>12.1</td>
#       <td>10.9</td>
#       <td>11.5</td>
#       <td>7.7</td>
#       <td>4.9</td>
#       <td>5.0</td>
#       <td>10.795628</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1</td>
#       <td>56</td>
#       <td>3.59</td>
#       <td>6.25</td>
#       <td>14.3</td>
#       <td>12.7</td>
#       <td>20.2</td>
#       <td>15.6</td>
#       <td>9.3</td>
#       <td>14.5</td>
#       <td>11.0</td>
#       <td>25.880579</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1</td>
#       <td>29</td>
#       <td>16.14</td>
#       <td>6.16</td>
#       <td>3.3</td>
#       <td>17.9</td>
#       <td>6.2</td>
#       <td>9.2</td>
#       <td>11.5</td>
#       <td>2.2</td>
#       <td>4.0</td>
#       <td>3.468565</td>
#     </tr>
#   </tbody>
# </table>

# %%
def fitness(df, key_obs, key_pred):
    R = np.corrcoef(df[key_obs],df[key_pred])[0,1]
    return dict(R=R)

# %%
batch_apply(df, fitness)
# Out:
#                        R
# CKD_EPI_Cys     0.822771
# CKD_EPI_Cr_Cys  0.844254
# FAS_Cys         0.786980
# FAS_Cr_Cys      0.831135
# SVR             0.865759

# %%
for key, _df in zip(["All subjects", "Age<60 y", "Age>=60y"],[df, df[df['age']<60], df[df['age']>=60]]):
    print(key)
    display.display(batch_apply(_df, fitness))
# Out:
# All subjects
#                        R
# CKD_EPI_Cys     0.822771
# CKD_EPI_Cr_Cys  0.844254
# FAS_Cys         0.786980
# FAS_Cr_Cys      0.831135
# SVR             0.865759
# Age<60 y
#                        R
# CKD_EPI_Cys     0.792320
# CKD_EPI_Cr_Cys  0.806745
# FAS_Cys         0.743160
# FAS_Cr_Cys      0.794031
# SVR             0.833056
# Age>=60y
#                        R
# CKD_EPI_Cys     0.798121
# CKD_EPI_Cr_Cys  0.832341
# FAS_Cys         0.782580
# FAS_Cr_Cys      0.833953
# SVR             0.852883

# %%
def Bias_Precision_Accuracy(df, key_obs, key_pred):
    # Median difference, IQR of the difference, P30, RMSE
    diff = df[key_pred] - df[key_obs]
    
    r = (df[key_obs].max() - df[key_obs].min())*0.15
    left = df[key_obs] - r
    right = df[key_obs] + r
    p30 = np.mean((df[key_pred] > left) & (df[key_pred] < right))
    
    return dict(Bias = diff.median(),
                IQR = np.quantile(diff, 0.75) - np.quantile(diff, 0.25),
                P30 = p30 *100,
                RMSE = np.sqrt(np.mean(diff**2)))

# %%
Bias_Precision_Accuracy(df, 'rGFR', 'SVR')
# Out:
# {'Bias': -0.17644451961754726,
#  'IQR': 16.219300632067856,
#  'P30': 87.2836719337848,
#  'RMSE': 14.615718515667071}

# %%
for key, _df in zip(["All subjects", "rGFR>=60", "rGFR<60"],[df, df[df['rGFR']>=60], df[df['rGFR']<60]]):
    print(key)
    display.display(batch_apply(_df, Bias_Precision_Accuracy))
# Out:
# All subjects
#                     Bias        IQR        P30       RMSE
# CKD_EPI_Cys     0.393093  29.607459  69.149737  22.736234
# CKD_EPI_Cr_Cys -2.828487  21.887123  78.781038  19.083700
# FAS_Cys         1.461448  26.308302  71.256584  27.220508
# FAS_Cr_Cys     -2.943543  20.672210  79.382995  18.784712
# SVR            -0.176445  16.219301  87.283672  14.615719
# rGFR>=60
#                     Bias        IQR        P30       RMSE
# CKD_EPI_Cys     6.520864  32.004656  40.179718  24.340743
# CKD_EPI_Cr_Cys -0.470286  27.331665  48.138639  20.206874
# FAS_Cys         4.132352  34.735986  42.618742  32.247556
# FAS_Cr_Cys     -3.709919  25.950670  50.192555  20.807367
# SVR            -3.311359  16.782990  68.421053  15.112729
# rGFR<60
#                     Bias        IQR        P30       RMSE
# CKD_EPI_Cys    -4.284529  20.989222  39.272727  20.247239
# CKD_EPI_Cr_Cys -5.783487  15.710296  46.545455  17.369032
# FAS_Cys        -0.462415  18.209322  47.272727  17.819535
# FAS_Cr_Cys     -2.645289  15.351126  50.727273  15.473895
# SVR             3.836448  13.747040  54.909091  13.881353

# %%
class HTMLDocument:
    
    def __init__(self):
        self.head = '''<head>
<link rel="stylesheet" href="css/style.min.css" type="text/css">
</head>
'''
        self.header = '''<html>'''+self.head+'''<body>'''
        self.footer = '''</body></html>'''
        self.el_list = []
        
    def add(self, el):
        self.el_list.append(el)
        
    def render(self):
        return '\n'.join([self.header] + self.el_list + [self.footer])
    
    def add_p(self, s):
        self.add('<p>{}</p>'.format(s))

# %%
doc = HTMLDocument()

doc.add(batch_apply(df, desc).to_html())

#doc.add(batch_apply(df, fitness).to_html())

for key, _df in zip(["All subjects", "Age<60 y", "Age>=60y"],[df, df[df['age']<60], df[df['age']>=60]]):
    doc.add_p(key)
    doc.add(batch_apply(_df, fitness).to_html())
    
for key, _df in zip(["All subjects", "rGFR>=60", "rGFR<60"],[df, df[df['rGFR']>=60], df[df['rGFR']<60]]):
    doc.add_p(key)
    doc.add(batch_apply(_df, Bias_Precision_Accuracy).to_html())

# %%
display.HTML(doc.render())
# Out:
# <html><head>
# <link rel="stylesheet" href="css/style.min.css" type="text/css">
# </head>
# <body>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>All subjects</th>
#       <th>Age&lt;60 y</th>
#       <th>Age&gt;=60y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CKD_EPI_Cys</th>
#       <td>69.3962085948395(39.1517378356909)</td>
#       <td>80.90386106107096(39.14754940746409)</td>
#       <td>51.993331519253275(32.12753816195782)</td>
#     </tr>
#     <tr>
#       <th>CKD_EPI_Cr_Cys</th>
#       <td>64.27641958959802(35.48006790892703)</td>
#       <td>77.0652300118479(34.95017038821175)</td>
#       <td>44.936063563511276(26.36529880065677)</td>
#     </tr>
#     <tr>
#       <th>FAS_Cys</th>
#       <td>71.88361925596095(42.466317375049705)</td>
#       <td>86.3526842984172(44.56617013166695)</td>
#       <td>50.00223544884381(27.080307487568675)</td>
#     </tr>
#     <tr>
#       <th>FAS_Cr_Cys</th>
#       <td>63.847679107672455(33.528004610544365)</td>
#       <td>78.02836674241843(32.74794994389674)</td>
#       <td>42.40240480181842(20.953145653776453)</td>
#     </tr>
#     <tr>
#       <th>SVR</th>
#       <td>65.30995460395278(25.639187542415552)</td>
#       <td>74.75305834407989(24.30807419863831)</td>
#       <td>51.0292684185053(20.488751506424602)</td>
#     </tr>
#   </tbody>
# </table>
# <p>All subjects</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CKD_EPI_Cys</th>
#       <td>0.822771</td>
#     </tr>
#     <tr>
#       <th>CKD_EPI_Cr_Cys</th>
#       <td>0.844254</td>
#     </tr>
#     <tr>
#       <th>FAS_Cys</th>
#       <td>0.786980</td>
#     </tr>
#     <tr>
#       <th>FAS_Cr_Cys</th>
#       <td>0.831135</td>
#     </tr>
#     <tr>
#       <th>SVR</th>
#       <td>0.865759</td>
#     </tr>
#   </tbody>
# </table>
# <p>Age<60 y</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CKD_EPI_Cys</th>
#       <td>0.792320</td>
#     </tr>
#     <tr>
#       <th>CKD_EPI_Cr_Cys</th>
#       <td>0.806745</td>
#     </tr>
#     <tr>
#       <th>FAS_Cys</th>
#       <td>0.743160</td>
#     </tr>
#     <tr>
#       <th>FAS_Cr_Cys</th>
#       <td>0.794031</td>
#     </tr>
#     <tr>
#       <th>SVR</th>
#       <td>0.833056</td>
#     </tr>
#   </tbody>
# </table>
# <p>Age>=60y</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>R</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CKD_EPI_Cys</th>
#       <td>0.798121</td>
#     </tr>
#     <tr>
#       <th>CKD_EPI_Cr_Cys</th>
#       <td>0.832341</td>
#     </tr>
#     <tr>
#       <th>FAS_Cys</th>
#       <td>0.782580</td>
#     </tr>
#     <tr>
#       <th>FAS_Cr_Cys</th>
#       <td>0.833953</td>
#     </tr>
#     <tr>
#       <th>SVR</th>
#       <td>0.852883</td>
#     </tr>
#   </tbody>
# </table>
# <p>All subjects</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bias</th>
#       <th>IQR</th>
#       <th>P30</th>
#       <th>RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CKD_EPI_Cys</th>
#       <td>0.393093</td>
#       <td>29.607459</td>
#       <td>69.149737</td>
#       <td>22.736234</td>
#     </tr>
#     <tr>
#       <th>CKD_EPI_Cr_Cys</th>
#       <td>-2.828487</td>
#       <td>21.887123</td>
#       <td>78.781038</td>
#       <td>19.083700</td>
#     </tr>
#     <tr>
#       <th>FAS_Cys</th>
#       <td>1.461448</td>
#       <td>26.308302</td>
#       <td>71.256584</td>
#       <td>27.220508</td>
#     </tr>
#     <tr>
#       <th>FAS_Cr_Cys</th>
#       <td>-2.943543</td>
#       <td>20.672210</td>
#       <td>79.382995</td>
#       <td>18.784712</td>
#     </tr>
#     <tr>
#       <th>SVR</th>
#       <td>-0.176445</td>
#       <td>16.219301</td>
#       <td>87.283672</td>
#       <td>14.615719</td>
#     </tr>
#   </tbody>
# </table>
# <p>rGFR>=60</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bias</th>
#       <th>IQR</th>
#       <th>P30</th>
#       <th>RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CKD_EPI_Cys</th>
#       <td>6.520864</td>
#       <td>32.004656</td>
#       <td>40.179718</td>
#       <td>24.340743</td>
#     </tr>
#     <tr>
#       <th>CKD_EPI_Cr_Cys</th>
#       <td>-0.470286</td>
#       <td>27.331665</td>
#       <td>48.138639</td>
#       <td>20.206874</td>
#     </tr>
#     <tr>
#       <th>FAS_Cys</th>
#       <td>4.132352</td>
#       <td>34.735986</td>
#       <td>42.618742</td>
#       <td>32.247556</td>
#     </tr>
#     <tr>
#       <th>FAS_Cr_Cys</th>
#       <td>-3.709919</td>
#       <td>25.950670</td>
#       <td>50.192555</td>
#       <td>20.807367</td>
#     </tr>
#     <tr>
#       <th>SVR</th>
#       <td>-3.311359</td>
#       <td>16.782990</td>
#       <td>68.421053</td>
#       <td>15.112729</td>
#     </tr>
#   </tbody>
# </table>
# <p>rGFR<60</p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bias</th>
#       <th>IQR</th>
#       <th>P30</th>
#       <th>RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CKD_EPI_Cys</th>
#       <td>-4.284529</td>
#       <td>20.989222</td>
#       <td>39.272727</td>
#       <td>20.247239</td>
#     </tr>
#     <tr>
#       <th>CKD_EPI_Cr_Cys</th>
#       <td>-5.783487</td>
#       <td>15.710296</td>
#       <td>46.545455</td>
#       <td>17.369032</td>
#     </tr>
#     <tr>
#       <th>FAS_Cys</th>
#       <td>-0.462415</td>
#       <td>18.209322</td>
#       <td>47.272727</td>
#       <td>17.819535</td>
#     </tr>
#     <tr>
#       <th>FAS_Cr_Cys</th>
#       <td>-2.645289</td>
#       <td>15.351126</td>
#       <td>50.727273</td>
#       <td>15.473895</td>
#     </tr>
#     <tr>
#       <th>SVR</th>
#       <td>3.836448</td>
#       <td>13.747040</td>
#       <td>54.909091</td>
#       <td>13.881353</td>
#     </tr>
#   </tbody>
# </table>
# </body></html>

# %%
with open('table.html', 'w') as f:
    f.write(doc.render())

# %%
model_t.base_model
# Out:
# SVR(C=100.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.05, gamma=0.1,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
model_t.base_model.support_vectors_.shape
# Out:
# (1066, 4)

# %%
model_t.base_model.dual_coef_.shape
# Out:
# (1, 1066)

# %%
model_t.base_model.gamma
# Out:
# 0.1

# %%
model_t.base_model.intercept_
# Out:
# array([5.0567044])

# %%
np.log(df[['Scr', 'Cys']]).describe()
# Out:
#                Scr          Cys
# count  1329.000000  1329.000000
# mean      0.346305     0.253820
# std       0.554502     0.692911
# min      -1.049822    -1.386294
# 25%      -0.051293    -0.210721
# 50%       0.190620     0.076961
# 75%       0.698135     0.536493
# max       2.162173     2.781301

# %%
df[['age', 'sex']].describe()
# Out:
#                age          sex
# count  1329.000000  1329.000000
# mean     53.899172     1.389014
# std      16.325116     0.487710
# min      14.000000     1.000000
# 25%      41.000000     1.000000
# 50%      55.000000     1.000000
# 75%      67.000000     2.000000
# max      91.000000     2.000000

# %%
df.head()
# Out:
#    sex  age    Cys   Scr  rGFR  FAScr  FAScys  FAScrcys  EPIcr  EPIcys  \
# 0    1   38   3.35  8.69  83.7   11.4    26.9      16.0    7.1    17.1
# 1    1   38   3.35  8.69  63.0   11.4    26.9      16.0    7.1    17.1
# 2    1   59   8.89  6.72  11.7   11.4     7.9       9.3    8.4     4.3
# 3    2   43  11.48  6.55   9.9   11.1     7.4       8.9    7.1     3.0
# 4    1   32   7.38  6.40  10.5   16.6    13.1      14.7   10.7     6.1
#
#    EPIcrcys        SVR  CKD_EPI_Cr  CKD_EPI_Cys  CKD_EPI_Cr_Cys     FAS_cr  \
# 0      10.0  66.235816    6.961372    17.051025       10.316914  11.112773
# 1      10.0  66.235816    6.961372    17.051025       10.316914  11.112773
# 2       5.0   8.827089    8.196237     4.288590        5.414697  11.424966
# 3       4.0  10.407108    7.129646     3.034728        4.112984  11.059291
# 4       7.0  12.091119   10.509999     6.118925        7.287303  15.089062
#
#      FAS_Cys  FAS_Cr_Cys
# 0  26.264478   15.617584
# 1  26.264478   15.617584
# 2   7.868533    9.318965
# 3   7.391669    8.860961
# 4  11.922222   13.320000

# %%
import math

# prevent numpy to make transfering it to JavaScript easily

def rbf(X,Y, gamma):    
    # X,Y is a Python/JavaScript list instead of numpy.array
    
    norm = 0.0
    for i in range(len(X)):
        norm += (X[i] - Y[i])**2
    
    return math.exp(-gamma * norm)

def predict(X, support_vectors, dual_coef, intercept, gamma):
    '''
    kernel_mat = rbf(X, support_vectors, gamma)
    pred = kernel_mat @ dual_coef.transpose() + intercept
    return pred
    '''
    kernel_mat = []
    pred = intercept
    for i in range(len(support_vectors)):
        w = rbf(X, support_vectors[i], gamma)
        pred += w * dual_coef[i]
    return pred

# %%
log_Scr_mean = 0.346305
log_Scr_std = 0.554502
log_Cys_mean = 0.253820
log_Cys_std = 0.692911

age_mean = 53.899172
age_std = 16.325116
sex_mean = 1.389014
sex_std = 0.487710

# %%
support_vectors = model_t.base_model.support_vectors_.tolist()
dual_coef = model_t.base_model.dual_coef_[0].tolist()
intercept = model_t.base_model.intercept_[0]
gamma = model_t.base_model.gamma

# %%
#support_vectors,dual_coef,intercept,gamma

# %%
np.array(support_vectors).shape, np.array(dual_coef).shape,intercept,gamma
# Out:
# ((1066, 4), (1066,), 5.056704398903536, 0.1)

# %%
key_list = ['age', 'Scr', 'Cys', 'sex']
scale_map = dict(age = 'linear', Scr = 'log', Cys = 'log', sex = 'linear')

mean_map = {}
std_map = {}

for key in key_list:
    if scale_map[key] == 'log':
        x = np.log(df[key])
    else:
        x = df[key]
        
    mean_map[key] = x.mean()
    std_map[key] = x.std()
    
y_log = True

# %%
mean_map, std_map
# Out:
# ({'age': 53.89917231000752,
#   'Scr': 0.34630462846000515,
#   'Cys': 0.2538197312345424,
#   'sex': 1.3890142964635064},
#  {'age': 16.32511575563543,
#   'Scr': 0.5545015820484048,
#   'Cys': 0.6929106463771294,
#   'sex': 0.4877101097484836})

# %%
inp = dict(age = 38, Scr = 8.69, Cys = 3.35, sex = 1)

inp_scaled = {}
for key in inp:
    if scale_map[key] == 'log':
        x = math.log(inp[key])
    else:
        x = inp[key]
    
    x_scaled = (x - mean_map[key])/std_map[key]
    inp_scaled[key] = x_scaled
    
inp_scaled
# Out:
# {'age': -0.973908702884335,
#  'Scr': 3.2747757077792805,
#  'Cys': 1.3784470185244921,
#  'sex': -0.7976342681600849}

# %%
inp_vec = []
for key in key_list:
    inp_vec.append(inp_scaled[key])
    
inp_vec
# Out:
# [-0.973908702884335,
#  3.2747757077792805,
#  1.3784470185244921,
#  -0.7976342681600849]

# %%
y_raw = predict(inp_vec, support_vectors, dual_coef, intercept, gamma)

# %%
if y_log:
    y = math.exp(y_raw)
else:
    y = y_raw

# %%
y
# Out:
# 66.1966952064643

# %%
import json

# %%
frozen = dict(
    support_vectors = support_vectors,
    dual_coef = dual_coef,
    intercept = intercept,
    gamma = gamma,
    
    key_list = key_list,
    scale_map = scale_map,
    mean_map = mean_map,
    std_map = std_map,
    
    y_log = y_log
)

# %%
jsons = json.dumps(frozen)
jsonps = 'var frozen='+jsons+';'
with open('frozen_model.js', 'w') as f:
    f.write(jsonps)

# %%
df.to_excel("df.xlsx")
