# %%
import pandas as pd
import numpy as np

# %%
import pandas_profiling

# %%
df = pd.read_excel('数据1：共1329人，以SVR开发新模型.xlsx')
#df.columns = ['id', 'age', 'sex', 'rGFR', 'Scr', 'Cys']
#df.shape

# %%
df.head()
# Out:
#    性别  年龄    Cys   Scr   GFR  FAScr  FAScys  FAScrcys  EPIcr  EPIcys  EPIcrcys
# 0   1  38   3.35  8.69  83.7   11.4    26.9      16.0    7.1    17.1        10
# 1   1  38   3.35  8.69  63.0   11.4    26.9      16.0    7.1    17.1        10
# 2   1  59   8.89  6.72  11.7   11.4     7.9       9.3    8.4     4.3         5
# 3   2  43  11.48  6.55   9.9   11.1     7.4       8.9    7.1     3.0         4
# 4   1  32   7.38  6.40  10.5   16.6    13.1      14.7   10.7     6.1         7

# %%
df['EPIcrcys'] = df['EPIcrcys'].astype(float)

# %%
df.head()
# Out:
#    性别  年龄    Cys   Scr   GFR  FAScr  FAScys  FAScrcys  EPIcr  EPIcys  EPIcrcys
# 0   1  38   3.35  8.69  83.7   11.4    26.9      16.0    7.1    17.1      10.0
# 1   1  38   3.35  8.69  63.0   11.4    26.9      16.0    7.1    17.1      10.0
# 2   1  59   8.89  6.72  11.7   11.4     7.9       9.3    8.4     4.3       5.0
# 3   2  43  11.48  6.55   9.9   11.1     7.4       8.9    7.1     3.0       4.0
# 4   1  32   7.38  6.40  10.5   16.6    13.1      14.7   10.7     6.1       7.0

# %%
df.dtypes
# Out:
# 性别            int64
# 年龄            int64
# Cys         float64
# Scr         float64
# GFR         float64
# FAScr       float64
# FAScys      float64
# FAScrcys    float64
# EPIcr       float64
# EPIcys      float64
# EPIcrcys    float64
# dtype: object

# %%
for key in ['Cys', 'Scr', 'GFR']:
    df['log_{}'.format(key)] = np.log(df[key])

# %%
df.head()
# Out:
#    性别  年龄    Cys   Scr   GFR  FAScr  FAScys  FAScrcys  EPIcr  EPIcys  \
# 0   1  38   3.35  8.69  83.7   11.4    26.9      16.0    7.1    17.1
# 1   1  38   3.35  8.69  63.0   11.4    26.9      16.0    7.1    17.1
# 2   1  59   8.89  6.72  11.7   11.4     7.9       9.3    8.4     4.3
# 3   2  43  11.48  6.55   9.9   11.1     7.4       8.9    7.1     3.0
# 4   1  32   7.38  6.40  10.5   16.6    13.1      14.7   10.7     6.1
#
#    EPIcrcys   log_Cys   log_Scr   log_GFR
# 0      10.0  1.208960  2.162173  4.427239
# 1      10.0  1.208960  2.162173  4.143135
# 2       5.0  2.184927  1.905088  2.459589
# 3       4.0  2.440606  1.879465  2.292535
# 4       7.0  1.998774  1.856298  2.351375

# %%
df.describe()
# Out:
#                 性别           年龄          Cys          Scr          GFR  \
# count  1329.000000  1329.000000  1329.000000  1329.000000  1329.000000
# mean      1.389014    53.899172     1.742175     1.681941    65.791497
# std       0.487710    16.325116     1.824874     1.161684    29.190437
# min       1.000000    14.000000     0.250000     0.350000     3.300000
# 25%       1.000000    41.000000     0.810000     0.950000    43.100000
# 50%       1.000000    55.000000     1.080000     1.210000    68.200000
# 75%       2.000000    67.000000     1.710000     2.010000    86.400000
# max       2.000000    91.000000    16.140000     8.690000   148.200000
#
#              FAScr       FAScys     FAScrcys        EPIcr       EPIcys  \
# count  1329.000000  1329.000000  1329.000000  1329.000000  1329.000000
# mean     63.307524    74.634312    66.322047    61.312340    69.396087
# std      36.140242    46.653197    37.080235    33.514183    39.152736
# ...

# %%
df.profile_report(title="WTF dataset")
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;WTF dataset&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
